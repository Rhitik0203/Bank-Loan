# %% [markdown]
# Bank Loan

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loan_data = pd.read_csv('financial_loan.csv')
loan_data.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %% [markdown]
# Basic Data Understanding

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
loan_data.describe()
# Out:
#                  id     member_id  annual_income           dti   installment  \
# count  3.857600e+04  3.857600e+04   3.857600e+04  38576.000000  38576.000000
# mean   6.810371e+05  8.476515e+05   6.964454e+04      0.133274    326.862965
# std    2.113246e+05  2.668105e+05   6.429368e+04      0.066662    209.092000
# min    5.473400e+04  7.069900e+04   4.000000e+03      0.000000     15.690000
# 25%    5.135170e+05  6.629788e+05   4.150000e+04      0.082100    168.450000
# 50%    6.627280e+05  8.473565e+05   6.000000e+04      0.134200    283.045000
# 75%    8.365060e+05  1.045652e+06   8.320050e+04      0.185900    434.442500
# max    1.077501e+06  1.314167e+06   6.000000e+06      0.299900   1305.190000
#
#            int_rate   loan_amount     total_acc  total_payment
# count  38576.000000  38576.000000  38576.000000   38576.000000
# mean       0.120488  11296.066855     22.132544   12263.348533
# std        0.037164   7460.746022     11.392282    9051.104777
# ...

# %% [markdown]
# Handling Missing Values

# %%
loan_data.isnull().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %%
loan_data = loan_data.dropna(subset=['emp_title'])

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
#Distribution of Key Numerical Variables
plt.figure(figsize=(14, 10))
plt.subplot(2, 2, 1)
sns.histplot(loan_data['annual_income'], bins=50, kde=True)
plt.title('Annual Income Distribution')

plt.subplot(2, 2, 2)
sns.histplot(loan_data['loan_amount'], bins=50, kde=True)
plt.title('Loan Amount Distribution')

plt.subplot(2, 2, 3)
sns.histplot(loan_data['int_rate'], bins=30, kde=True)
plt.title('Interest Rate Distribution')

plt.subplot(2, 2, 4)
sns.histplot(loan_data['dti'], bins=30, kde=True)
plt.title('Debt-to-Income Ratio Distribution')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#Categorical Variables Distribution
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='grade', data=loan_data, palette="viridis")
plt.title('Loan Grade Distribution')

plt.subplot(1, 2, 2)
sns.countplot(x='loan_status', data=loan_data, palette="magma")
plt.title('Loan Status Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# Correlation Analysis

# %%
# Check for non-numeric columns
print(loan_data.select_dtypes(exclude=['number']).columns)
# Out:
# Index(['address_state', 'application_type', 'emp_length', 'emp_title', 'grade',
#        'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'purpose',
#        'sub_grade', 'term', 'verification_status'],
#       dtype='object')

# %%
# Select only numeric columns for correlation
numeric_data = loan_data.select_dtypes(include=['number'])

# %%
correlation_matrix = numeric_data.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Key Numerical Variables")
plt.show()

# %% [markdown]
# Additional Analysis

# %%
# Analyzing average loan amount and interest rate per loan grade
loan_grade_summary = loan_data.groupby('grade')[['loan_amount', 'int_rate']].mean()
print("\nAverage Loan Amount and Interest Rate by Grade:")
print(loan_grade_summary)
# Out:
# Average Loan Amount and Interest Rate by Grade:
#         loan_amount  int_rate
# grade
# A       8709.139062  0.073468
# B      11165.682567  0.110271
# C      11043.312771  0.135508
# D      12272.206118  0.157112
# E      15784.106944  0.177003
# F      18519.503546  0.197341
# G      20348.923841  0.214031

# %%
# Analyzing loan status distribution across loan purposes
loan_status_purpose = loan_data.groupby(['purpose', 'loan_status']).size().unstack(fill_value=0)
print("\nLoan Status by Purpose:")
print(loan_status_purpose)
# Out:
# Loan Status by Purpose:
# loan_status         Charged Off  Current  Fully Paid
# purpose
# Debt consolidation         2563      559       14640
# car                         152       48        1261
# credit card                 488      100        4232
# educational                  48        0         249
# home improvement            307       91        2356
# house                        53       13         282
# major purchase              195       35        1803
# medical                      96       12         536
# moving                       82        6         452
# other                       562      113        3007
# renewable_energy             15        1          72
# small business              371       63        1028
# vacation                     49        4         289
# wedding                      86       21         798
